# %%
# %pip install numpy scipy pandas matplotlib tqdm 
pip install ipywidgets
# Out:
# Requirement already satisfied: numpy in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (2.4.1)
# Requirement already satisfied: scipy in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (1.17.0)
# Collecting pandas
#   Using cached pandas-3.0.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (3.10.8)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: colorama in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\neural_odes2\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.0-cp313-cp313-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 6.4 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.7 MB 7.0 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.7 MB 7.6 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.7 MB 7.5 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.7 MB 7.9 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.7 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 7.9 MB/s  0:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, tqdm, pandas
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [tqdm]
#    ------------- -------------------------- 1/3 [tqdm]
#    ------------- -------------------------- 1/3 [tqdm]
#    ------------- -------------------------- 1/3 [tqdm]
#    ------------- -------------------------- 1/3 [tqdm]
#    ------------- -------------------------- 1/3 [tqdm]
#    ------------- -------------------------- 1/3 [tqdm]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    ---------------------------------------- 3/3 [pandas]
#
# Successfully installed pandas-3.0.0 tqdm-4.67.1 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision
# Out:
# Collecting torch
#   Using cached torch-2.10.0-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting torchvision
#   Using cached torchvision-0.25.0-cp313-cp313-win_amd64.whl.metadata (5.4 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting setuptools (from torch)
#   Using cached setuptools-80.10.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting numpy (from torchvision)
#   Using cached numpy-2.4.1-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Using cached pillow-12.1.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached markupsafe-3.0.3-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Using cached torch-2.10.0-cp313-cp313-win_amd64.whl (113.8 MB)
# Using cached torchvision-0.25.0-cp313-cp313-win_amd64.whl (4.3 MB)
# Using cached fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached pillow-12.1.0-cp313-cp313-win_amd64.whl (7.0 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached filelock-3.20.3-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp313-cp313-win_amd64.whl (15 kB)
# Using cached numpy-2.4.1-cp313-cp313-win_amd64.whl (12.3 MB)
# Using cached setuptools-80.10.1-py3-none-any.whl (1.1 MB)
# Installing collected packages: mpmath, typing-extensions, sympy, setuptools, pillow, numpy, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision
#
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    ----------------------------------------  0/13 [mpmath]
#    --- ------------------------------------  1/13 [typing-extensions]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    ------ ---------------------------------  2/13 [sympy]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    --------- ------------------------------  3/13 [setuptools]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    ------------ ---------------------------  4/13 [pillow]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    --------------- ------------------------  5/13 [numpy]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    ------------------ ---------------------  6/13 [networkx]
#    --------------------- ------------------  7/13 [MarkupSafe]
#    ------------------------ ---------------  8/13 [fsspec]
#    ------------------------ ---------------  8/13 [fsspec]
#    ------------------------ ---------------  8/13 [fsspec]
#    ------------------------ ---------------  8/13 [fsspec]
#    ------------------------ ---------------  8/13 [fsspec]
#    ------------------------ ---------------  8/13 [fsspec]
#    ------------------------ ---------------  8/13 [fsspec]
#    ------------------------ ---------------  8/13 [fsspec]
#    ------------------------ ---------------  8/13 [fsspec]
#    ------------------------ ---------------  8/13 [fsspec]
#    --------------------------- ------------  9/13 [filelock]
#    --------------------------- ------------  9/13 [filelock]
#    ------------------------------ --------- 10/13 [jinja2]
#    ------------------------------ --------- 10/13 [jinja2]
#    ------------------------------ --------- 10/13 [jinja2]
#    ------------------------------ --------- 10/13 [jinja2]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
# ...
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    --------------------------------- ------ 11/13 [torch]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ------------------------------------ --- 12/13 [torchvision]
#    ---------------------------------------- 13/13 [torchvision]
#
# Successfully installed MarkupSafe-3.0.3 filelock-3.20.3 fsspec-2026.1.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 numpy-2.4.1 pillow-12.1.0 setuptools-80.10.1 sympy-1.14.0 torch-2.10.0 torchvision-0.25.0 typing-extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchdiffeq
# Out:
# Collecting torchdiffeq
#   Using cached torchdiffeq-0.2.5-py3-none-any.whl.metadata (440 bytes)
# Requirement already satisfied: torch>=1.5.0 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from torchdiffeq) (2.10.0)
# Collecting scipy>=1.4.0 (from torchdiffeq)
#   Using cached scipy-1.17.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from scipy>=1.4.0->torchdiffeq) (2.4.1)
# Requirement already satisfied: filelock in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from torch>=1.5.0->torchdiffeq) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from torch>=1.5.0->torchdiffeq) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from torch>=1.5.0->torchdiffeq) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from torch>=1.5.0->torchdiffeq) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from torch>=1.5.0->torchdiffeq) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from torch>=1.5.0->torchdiffeq) (2026.1.0)
# Requirement already satisfied: setuptools in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from torch>=1.5.0->torchdiffeq) (80.10.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.5.0->torchdiffeq) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jackr\onedrive\documents\github\jackross-phd-notes\.venv\lib\site-packages (from jinja2->torch>=1.5.0->torchdiffeq) (3.0.3)
# Using cached torchdiffeq-0.2.5-py3-none-any.whl (32 kB)
# Using cached scipy-1.17.0-cp313-cp313-win_amd64.whl (36.3 MB)
# Installing collected packages: scipy, torchdiffeq
#
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    ---------------------------------------- 0/2 [scipy]
#    -------------------- ------------------- 1/2 [torchdiffeq]
#    -------------------- ------------------- 1/2 [torchdiffeq]
#    -------------------- ------------------- 1/2 [torchdiffeq]
#    ---------------------------------------- 2/2 [torchdiffeq]
#
# Successfully installed scipy-1.17.0 torchdiffeq-0.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from matplotlib import pyplot as plt
from numpy import linalg as la
from scipy import stats
from scipy import spatial as sp
import pandas as pd

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.1754, 0.7674, 0.2227],
#         [0.9059, 0.4127, 0.0369],
#         [0.4015, 0.0055, 0.7562],
#         [0.9299, 0.6294, 0.2851],
#         [0.6044, 0.0447, 0.3844]])
