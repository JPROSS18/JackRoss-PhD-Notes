# %% [markdown]
# # File Info
#
# Sample Training code for neural ODEs.
#
# Learns non-choatic Lorenz

# %%
import os
import sys
from torchdiffeq import odeint as odeint

sys.path.append(os.path.abspath(".."))

import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm
from matplotlib import colors
from mpl_toolkits import mplot3d
from numpy import linalg as la
from scipy import stats
from scipy import spatial as sp
from scipy import integrate as integ
import pandas as pd
import torch
import torch.nn as nn
from tqdm import tqdm
from ipywidgets import interact, IntSlider
import types

import models.Neural_ODEs_v2 as nodes
import models.DynamicalSystems as ds

# %% [markdown]
# # Data Generation

# %%
lorenz = ds.Lorenz(sigma=10.0, rho=15.0, beta=8.0 / 3.0)

# %%
ic_test  = ic[0]
ic_test[3] = 28.0
t_eval_test = torch.arange(0, 25, 0.01)
ic_test
# Out:
# tensor([-10., -10., -10.,  28.])

# %%
test = odeint(lorenz.na_f, ic_test, t_eval_test)
test.shape
# Out:
# torch.Size([2500, 4])

# %%
#Plotting data by subplots 
#Normalised Plot
fig = plt.figure(figsize=(6, 8))
ax1 = fig.add_subplot(1, 1, 1, projection='3d')
ax1.plot(xs=test[:, 0], ys=test[:, 1], zs=test[:, 2], linewidth = 1, alpha = 1, color='royalblue')



ax1.view_init(elev = 30, azim = 120)

# %%
a = torch.linspace(-10, 10, 5)
r_val = torch.arange(10, 20, 2.0)
ic = torch.cartesian_prod(a, a, a, r_val)

lorenz.f = lorenz.na_f


dt = 0.05
sol = lorenz.solve(x0=ic, t_span=(0, 10), dt=dt)
sol.shape
# Out:
# torch.Size([200, 625, 4])

# %%
#Plotting data by subplots 
#Normalised Plot
fig = plt.figure(figsize=(6, 8))
ax1 = fig.add_subplot(1, 1, 1, projection='3d')
for i in range(sol.shape[1]):
    ax1.plot(xs=sol[:, i, 0], ys=sol[:, i, 1], zs=sol[:, i, 2], linewidth = 1, alpha = 0.1, color='royalblue')



ax1.view_init(elev = 30, azim = 120)

# %%
sol.shape
# Out:
# torch.Size([200, 625, 4])

# %%
def data_loader_format(data, pts=2):
    # Pairwise data
    # data input shape: (time, trajectories, dim)
    num_pts = pts
    data_tensor = torch.stack((data[0:-(num_pts-1), :, :], data[num_pts-1:, :, :]), dim=1)

    list = []
    for i in range(data_tensor.shape[2]):
        list.append(data_tensor[:,:,i,:])

    data_tensor1 = torch.concat(list, dim=0)
   
    return data_tensor1

# %%
data_tensor1 = data_loader_format(sol, pts=2) 
data_loader = torch.utils.data.DataLoader(data_tensor1, batch_size=512, shuffle=True)

# %%
data_loader.dataset.shape #Num pairs - traj - dim
# Out:
# torch.Size([124375, 2, 4])

# %% [markdown]
# # Model

# %%
model = nodes.driven_neural_ODE(input_dim=3, drivers=1, output_dim=3, hidden_dim=32, depth=4, activation_func=nn.Tanh())

# %%
t_eval = torch.arange(0, 0.1, dt)
print(t_eval)

#Saving loss and setting optimiser 
loss_list = []
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.MSELoss()
# Out:
# tensor([0.0000, 0.0500])

# %%
trainer = nodes.Trainer(model=model, data_loader=data_loader, optimizer=optimizer, loss_fn=loss_fn, t_eval=t_eval, dt=dt) #

# %%
trainer.train(num_epochs=400, t_eval=t_eval)
# Out:
# Current Loss: 0.7215837240219116  - Epochs: 0:  27%|██▋       | 109/400 [05:42<15:13,  3.14s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 trainer.train(num_epochs=400, t_eval=t_eval)
#
# File c:\Users\jackr\OneDrive\Documents\GitHub\JackRoss-PhD-Notes\models\Neural_ODEs_v2.py:198, in Trainer.train(self, num_epochs, t_eval)
#     196     #Backpropagation and optimization step
#     197     loss.backward()
# --> 198     self.optimizer.step()
#     200 avg_epoch_loss = epoch_loss / len(self.data_loader)
#     201 self.loss_list.append(avg_epoch_loss)
#
# File c:\Users\jackr\OneDrive\Documents\GitHub\JackRoss-PhD-Notes\.venv\Lib\site-packages\torch\optim\optimizer.py:526, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     521             raise RuntimeError(
#     522                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     523             )
#     525 # pyrefly: ignore [invalid-param-spec]
# --> 526 out = func(*args, **kwargs)
#     527 self._optimizer_step_code()
#     529 # call optimizer step post hooks
#
# File c:\Users\jackr\OneDrive\Documents\GitHub\JackRoss-PhD-Notes\.venv\Lib\site-packages\torch\optim\optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File c:\Users\jackr\OneDrive\Documents\GitHub\JackRoss-PhD-Notes\.venv\Lib\site-packages\torch\optim\adam.py:248, in Adam.step(self, closure)
#     236     beta1, beta2 = group["betas"]
#     238     has_complex = self._init_group(
#     239         group,
#     240         params_with_grad,
#    (...)    245         state_steps,
#     246     )
# --> 248     adam(
#     249         params_with_grad,
#     250         grads,
#     251         exp_avgs,
#     252         exp_avg_sqs,
#     253         max_exp_avg_sqs,
#     254         state_steps,
#     255         amsgrad=group["amsgrad"],
#     256         has_complex=has_complex,
#     257         beta1=beta1,
#     258         beta2=beta2,
#     259         lr=group["lr"],
#     260         weight_decay=group["weight_decay"],
#     261         eps=group["eps"],
#     262         maximize=group["maximize"],
#     263         foreach=group["foreach"],
#     264         capturable=group["capturable"],
#     265         differentiable=group["differentiable"],
#     266         fused=group["fused"],
#     267         grad_scale=getattr(self, "grad_scale", None),
#     268         found_inf=getattr(self, "found_inf", None),
#     269         decoupled_weight_decay=group["decoupled_weight_decay"],
#     270     )
#     272 return loss
#
# File c:\Users\jackr\OneDrive\Documents\GitHub\JackRoss-PhD-Notes\.venv\Lib\site-packages\torch\optim\optimizer.py:151, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     149     return disabled_func(*args, **kwargs)
#     150 else:
# --> 151     return func(*args, **kwargs)
#
# File c:\Users\jackr\OneDrive\Documents\GitHub\JackRoss-PhD-Notes\.venv\Lib\site-packages\torch\optim\adam.py:970, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     967 else:
#     968     func = _single_tensor_adam
# --> 970 func(
#     971     params,
#     972     grads,
#     973     exp_avgs,
#     974     exp_avg_sqs,
#     975     max_exp_avg_sqs,
#     976     state_steps,
#     977     amsgrad=amsgrad,
#     978     has_complex=has_complex,
#     979     beta1=beta1,
#     980     beta2=beta2,
#     981     lr=lr,
#     982     weight_decay=weight_decay,
#     983     eps=eps,
#     984     maximize=maximize,
#     985     capturable=capturable,
#     986     differentiable=differentiable,
#     987     grad_scale=grad_scale,
#     988     found_inf=found_inf,
#     989     decoupled_weight_decay=decoupled_weight_decay,
#     990 )
#
# File c:\Users\jackr\OneDrive\Documents\GitHub\JackRoss-PhD-Notes\.venv\Lib\site-packages\torch\optim\adam.py:457, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     453     device_beta1 = beta1
#     455 # Decay the first and second moment running average coefficient
# --> 457 exp_avg.lerp_(grad, 1 - device_beta1)
#     459 # Nested if is necessary to bypass jitscript rules
#     460 if differentiable and isinstance(beta2, Tensor):
#
# KeyboardInterrupt:

# %%
### Analysis  
epochs = len(trainer.loss_list)
fig = plt.figure(figsize=(15,6))
ax = fig.add_subplot(1, 2, 1)

ax.plot(np.linspace(0, epochs, len(trainer.loss_list)), trainer.loss_list)
ax.grid()

ax.set_xlabel('Epochs', fontsize=15)
ax.set_ylabel('Loss', fontsize=15)
ax.set_xlim(0, epochs)
ax.set_ylim(bottom=0)

ax2 = fig.add_subplot(1, 2, 2)

e_pts = np.linspace(0, epochs, len(trainer.loss_list))
ax2.plot(e_pts[1:], trainer.loss_list[1:])

#ax2.set_ylim()
ax2.grid()
#plt.xscale('log')~
#
ax2.set_yscale('log')
#ax2.set_xscale('log')
ax2.set_xlabel('Epochs', fontsize=15)
# Out:
# Text(0.5, 0, 'Epochs')

# %%
pred_x = odeint(func=model, y0=data_loader.dataset[:,0,:], t=t_eval, method='rk4', options={'step_size': dt})  #(time, batch, traj, dim)
loss = loss_fn(pred_x[-1, :, :, ], data_loader.dataset[:,1,:]) 
loss_list.append(loss.item())
print(f'Final Loss: {loss.item()}')
# Out:
# Final Loss: 0.0015238275518640876

# %% [markdown]
# # Analyzing the trained model

# %% [markdown]
# ## Data Generation with trained NODE

# %%
a = torch.linspace(-10, 10, 5)
r_val = torch.arange(10, 20, 2.0)
ic = torch.cartesian_prod(a, a, a, r_val)

        
torch.cartesian_prod(pts, r_vals_test)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[83], line 3
#       1 pts = torch.tensor([1])
#       2 r_vals_test = torch.tensor([10.0, 12.0, 14.0, 16.0, 18.0])
# ----> 3 torch.cartesian_prod(pts, r_vals_test)
#
# File c:\Users\jackr\OneDrive\Documents\GitHub\JackRoss-PhD-Notes\.venv\Lib\site-packages\torch\functional.py:1370, in cartesian_prod(*tensors)
#    1368 if has_torch_function(tensors):
#    1369     return handle_torch_function(cartesian_prod, tensors, *tensors)
# -> 1370 return _VF.cartesian_prod(tensors)
#
# RuntimeError: meshgrid expects all tensors to have the same dtype

# %%
t_Start_pred = 0; t_Final_pred = 20; dt_pred = 0.05
t_eval_pred = torch.arange(t_Start_pred, t_Final_pred, dt_pred)

node_data = odeint(func=model, y0=ic, t=t_eval_pred, method='rk4', options={'step_size': dt_pred})
true_data = odeint(func=lorenz.f, y0=ic, t=t_eval_pred, method='rk4', options={'step_size': dt_pred})



node_data = node_data.detach().numpy()
true_data = true_data.detach().numpy()

print(node_data.shape); print(true_data.shape)
# Out:
# (400, 625, 4)
# (400, 625, 4)

# %% [markdown]
# ## Plotting phase space

# %%
ic[:, 3] == 10.0
# Out:
# tensor([ True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False,  True, False, False, False, False,
#          True, False, False, False, False])

# %%
ic[:, 3] == .shape
# Out:
#   Cell In[86], line 1
#     ic[:, 3] == .shape
#                 ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
ax2 = fig.add_subplot(1, 2, 2, projection='3d')

#ax1.plot(node_data[:, :, 0],
 #               node_data[:, :, 1], node_data[:, :, 2],
 #               linewidth=0.5, linestyle='--', color='royalblue')

#Normalised Plot

for i in range(true_data.shape[1]):
    ax1.plot(xs=true_data[:, i,  0], ys=true_data[:, i, 1], zs=true_data[:, i, 2], linewidth = 1, alpha = 0.1 )

for i in range(node_data.shape[1]):
    ax2.plot(xs=node_data[:, i,  0], ys=node_data[:, i, 1], zs=node_data[:, i, 2], linewidth = 1, alpha = 0.1)


ax1.view_init(elev = 30, azim = 120)
ax1.set_title(f"True r(0)={10.0}")
ax2.set_title(f"NODE r(0)={10.0}")
plt.show()

# %%
# Plotting time traces:

# %%
true_data.shape
# Out:
# (400, 625, 4)

# %%
r_plots = [10.0, 12.0, 14.0, 16.0, 18.0]
fig, axes = plt.subplots(len(r_plots), 2, figsize=(15, 5*len(r_plots)), subplot_kw={'projection': '3d'}, sharex=True, sharey=True)


fig = plt.figure(figsize=(15, 5))


for i, r in enumerate(r_plots):
    current_node_data = node_data[:, ic[:, 3] == r, :]
    current_true_data = true_data[:, ic[:, 3] == r, :]
    indices = np.random.randint(0, current_true_data.shape[1], 10)
    for k in indices:
            axes[i, 0].plot(current_node_data[:, k, 0],
                        current_node_data[:, k, 1], 
                        current_node_data[:, k, 2],
                        linewidth=0.5, alpha=1, linestyle='--')
            axes[i, 1].plot(current_true_data[:, k, 0],
                            current_true_data[:, k, 1],
                            current_true_data[:, k, 2],
                            linewidth=0.5, alpha=1, linestyle='--')
            axes[i, 0].set_title(f"Neural ODE r(0)={r}")
            axes[i, 1].set_title(f"True r(0)={r}")

  

plt.tight_layout()
plt.show()

# %%
r_plots = [10.0, 12.0, 14.0, 16.0, 18.0]
fig, axes = plt.subplots(len(r_plots), 2, figsize=(15, 5*len(r_plots)), subplot_kw={'projection': '3d'}, sharex=True, sharey=True)


fig = plt.figure(figsize=(15, 5))


for i, r in enumerate(r_plots):
    axes[i, 0].plot(node_data[:, ic[:, 3] == r, 0],
                    node_data[:, ic[:, 3] == r, 1], 
                    node_data[:, ic[:, 3] == r, 2],
                    linewidth=0.5, alpha=1, linestyle='--')
    axes[i, 1].plot(true_data[:, ic[:, 3] == r, 0],
                    true_data[:, ic[:, 3] == r, 1],
                    true_data[:, ic[:, 3] == r, 2],
                    linewidth=0.5, alpha=1, linestyle='--')
    axes[i, 0].set_title(f"Neural ODE r(0)={r}")
    axes[i, 1].set_title(f"True r(0)={r}")

plt.tight_layout()
plt.show()
